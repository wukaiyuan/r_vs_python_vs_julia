# %% [markdown]
# Read in a csv file
# ------------------

# %%
using DataFrames
nba = readtable("nba_2013.csv")
# Out:
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/StatsFuns.ji for module StatsFuns.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/DataFrames.ji for module DataFrames.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/StatsBase.ji for module StatsBase.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/ArrayViews.ji for module ArrayViews.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/DataArrays.ji for module DataArrays.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/GZip.ji for module GZip.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/SortingAlgorithms.ji for module SortingAlgorithms.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Docile.ji for module Docile.
# 481x31 DataFrames.DataFrame
# | Row | player              | pos  | age | bref_team_id | g  | gs | mp   | fg  |
# |-----|---------------------|------|-----|--------------|----|----|------|-----|
# | 1   | "Quincy Acy"        | "SF" | 23  | "TOT"        | 63 | 0  | 847  | 66  |
# | 2   | "Steven Adams"      | "C"  | 20  | "OKC"        | 81 | 20 | 1197 | 93  |
# | 3   | "Jeff Adrien"       | "PF" | 27  | "TOT"        | 53 | 12 | 961  | 143 |
# | 4   | "Arron Afflalo"     | "SG" | 28  | "ORL"        | 73 | 73 | 2552 | 464 |
# | 5   | "Alexis Ajinca"     | "C"  | 25  | "NOP"        | 56 | 30 | 951  | 136 |
# | 6   | "Cole Aldrich"      | "C"  | 25  | "NYK"        | 46 | 2  | 330  | 33  |
# | 7   | "LaMarcus Aldridge" | "PF" | 28  | "POR"        | 69 | 69 | 2498 | 652 |
# | 8   | "Lavoy Allen"       | "PF" | 24  | "TOT"        | 65 | 2  | 1072 | 134 |
# | 9   | "Ray Allen"         | "SG" | 38  | "MIA"        | 73 | 9  | 1936 | 240 |
# | 10  | "Tony Allen"        | "SG" | 32  | "MEM"        | 55 | 28 | 1278 | 204 |
# | 11  | "Al-Farouq Aminu"   | "SF" | 23  | "NOP"        | 80 | 65 | 2045 | 234 |
# ⋮
# | 470 | "Shawne Williams"   | "PF" | 27  | "LAL"        | 36 | 13 | 751  | 73  |
# | 471 | "Jeff Withey"       | "C"  | 23  | "NOP"        | 58 | 4  | 684  | 69  |
# | 472 | "Nate Wolters"      | "PG" | 22  | "MIL"        | 58 | 31 | 1309 | 170 |
# | 473 | "Metta World Peace" | "SF" | 34  | "NYK"        | 29 | 1  | 388  | 56  |
# | 474 | "Brandan Wright"    | "C"  | 26  | "DAL"        | 58 | 0  | 1077 | 224 |
# | 475 | "Chris Wright"      | "SF" | 25  | "MIL"        | 8  | 0  | 126  | 21  |
# | 476 | "Dorell Wright"     | "SF" | 28  | "POR"        | 68 | 13 | 984  | 111 |
# | 477 | "Tony Wroten"       | "SG" | 20  | "PHI"        | 72 | 16 | 1765 | 345 |
# | 478 | "Nick Young"        | "SG" | 28  | "LAL"        | 64 | 9  | 1810 | 387 |
# | 479 | "Thaddeus Young"    | "PF" | 25  | "PHI"        | 79 | 78 | 2718 | 582 |
# | 480 | "Cody Zeller"       | "C"  | 21  | "CHA"        | 82 | 3  | 1416 | 172 |
# | 481 | "Tyler Zeller"      | "C"  | 24  | "CLE"        | 70 | 9  | 1049 | 156 |
#
# | Row | fga  | fg_   | x3p | x3pa | x3p_     | x2p | x2pa | x2p_     | efg_  |
# |-----|------|-------|-----|------|----------|-----|------|----------|-------|
# | 1   | 141  | 0.468 | 4   | 15   | 0.266667 | 62  | 126  | 0.492063 | 0.482 |
# | 7   | 296 | 360 | 0.822 | 166 | 599 | 765 | 178 | 63  | 68  | 123 | 147 |
# | 8   | 33  | 50  | 0.66  | 119 | 192 | 311 | 71  | 24  | 33  | 44  | 126 |
# | 9   | 105 | 116 | 0.905 | 23  | 182 | 205 | 143 | 54  | 8   | 84  | 115 |
# | 10  | 76  | 121 | 0.628 | 79  | 129 | 208 | 94  | 90  | 19  | 90  | 121 |
# | 11  | 91  | 137 | 0.664 | 129 | 367 | 496 | 114 | 82  | 38  | 88  | 147 |
# ⋮
# | 470 | 14  | 20  | 0.7   | 25  | 142 | 167 | 30  | 19  | 30  | 21  | 93  |
# | 471 | 52  | 73  | 0.712 | 49  | 101 | 150 | 26  | 15  | 50  | 20  | 73  |
# | 472 | 59  | 90  | 0.656 | 33  | 116 | 149 | 187 | 35  | 15  | 57  | 67  |
# | 473 | 10  | 16  | 0.625 | 18  | 41  | 59  | 17  | 24  | 8   | 19  | 44  |
# | 474 | 77  | 106 | 0.726 | 102 | 142 | 244 | 31  | 32  | 55  | 35  | 94  |
# | 475 | 6   | 15  | 0.4   | 10  | 10  | 20  | 5   | 7   | 5   | 5   | 17  |
# | 476 | 52  | 69  | 0.754 | 29  | 162 | 191 | 64  | 23  | 16  | 39  | 62  |
# | 477 | 209 | 326 | 0.641 | 69  | 159 | 228 | 217 | 78  | 16  | 204 | 151 |
# | 478 | 235 | 285 | 0.825 | 29  | 137 | 166 | 95  | 46  | 12  | 95  | 156 |
# | 479 | 163 | 229 | 0.712 | 166 | 310 | 476 | 182 | 167 | 36  | 165 | 213 |
# | 480 | 146 | 200 | 0.73  | 118 | 235 | 353 | 92  | 40  | 41  | 87  | 170 |
# | 481 | 87  | 121 | 0.719 | 103 | 179 | 282 | 36  | 18  | 38  | 60  | 137 |
#
# | Row | pts  | season      | season_end |
# |-----|------|-------------|------------|
# | 1   | 171  | "2013-2014" | 2013       |
# | 2   | 265  | "2013-2014" | 2013       |
# | 3   | 362  | "2013-2014" | 2013       |
# | 4   | 1330 | "2013-2014" | 2013       |
# | 5   | 328  | "2013-2014" | 2013       |
# | 6   | 92   | "2013-2014" | 2013       |
# | 7   | 1603 | "2013-2014" | 2013       |
# | 8   | 303  | "2013-2014" | 2013       |
# | 9   | 701  | "2013-2014" | 2013       |
# | 10  | 495  | "2013-2014" | 2013       |
# | 11  | 572  | "2013-2014" | 2013       |
# ⋮
# | 470 | 202  | "2013-2014" | 2013       |
# | 471 | 190  | "2013-2014" | 2013       |
# | 472 | 417  | "2013-2014" | 2013       |
# | 473 | 139  | "2013-2014" | 2013       |
# | 474 | 525  | "2013-2014" | 2013       |
# | 475 | 48   | "2013-2014" | 2013       |
# | 476 | 343  | "2013-2014" | 2013       |
# | 477 | 939  | "2013-2014" | 2013       |
# | 478 | 1144 | "2013-2014" | 2013       |
# | 479 | 1417 | "2013-2014" | 2013       |
# | 480 | 490  | "2013-2014" | 2013       |
# | 481 | 399  | "2013-2014" | 2013       |

# %% [markdown]
# Find the number of players
# -------------------------

# %%
size(nba)
# Out:
# (481,31)

# %% [markdown]
# Look at the first row of the data
# -------------------------------

# %%
head(nba,1)
# Out:
# 1x31 DataFrames.DataFrame
# | Row | player       | pos  | age | bref_team_id | g  | gs | mp  | fg | fga |
# |-----|--------------|------|-----|--------------|----|----|-----|----|-----|
# | 1   | "Quincy Acy" | "SF" | 23  | "TOT"        | 63 | 0  | 847 | 66 | 141 |
#
# | Row | fg_   | x3p | x3pa | x3p_     | x2p | x2pa | x2p_     | efg_  | ft |
# |-----|-------|-----|------|----------|-----|------|----------|-------|----|
# | 1   | 0.468 | 4   | 15   | 0.266667 | 62  | 126  | 0.492063 | 0.482 | 35 |
#
# | Row | fta | ft_  | orb | drb | trb | ast | stl | blk | tov | pf  | pts |
# |-----|-----|------|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | 1   | 53  | 0.66 | 72  | 144 | 216 | 28  | 23  | 26  | 30  | 122 | 171 |
#
# | Row | season      | season_end |
# |-----|-------------|------------|
# | 1   | "2013-2014" | 2013       |

# %% [markdown]
# Find the average of each statistic
# --------------------------------

# %%
colwise(mean,nba[:, filter(x -> !(x in [:player,:pos,:bref_team_id,:season]), names(nba))])
# Out:
# 27-element Array{Any,1}:
#  [26.509355509355508]
#  [53.25363825363825]
#  [25.571725571725572]
#  [1237.3866943866944]
#  [192.88149688149687]
#  [424.4636174636175]
#  [NA]
#  [39.61330561330561]
#  [110.13097713097713]
#  [NA]
#  [153.26819126819126]
#  [314.3326403326403]
#  [NA]
#  ⋮
#  [120.64241164241164]
#  [NA]
#  [55.810810810810814]
#  [162.8170478170478]
#  [218.62785862785861]
#  [112.53638253638253]
#  [39.28066528066528]
#  [24.103950103950105]
#  [71.86278586278586]
#  [105.86902286902287]
#  [516.5821205821206]
#  [2013.0]

# %% [markdown]
# Make pairwise scatterplots
# -------------------------

# %%
using Gadfly, Compose
function scatterplot_matrix(df::AbstractDataFrame, cols::Vector{Symbol})
    n = length(cols)
    cs = Array(Context, (n, n))
    for (i, coli) in enumerate(cols), (j, colj) in enumerate(cols)
        if i==j
            cs[i, j] = compose(context(), text(0.5, 0.5, string(coli), hcenter, vcenter), linewidth(0.01mm), 
            stroke(color("black")), fontsize(5))
        else
            cs[i, j] = render(plot(x=df[coli], y=df[colj], Guide.xlabel(nothing), Guide.ylabel(nothing), 
                Guide.yticks(label=false), Guide.xticks(label=false)))
        end
    end
    draw(SVGJS((5*n)cm, (5*n)cm), gridstack(cs))
end

scatterplot_matrix(nba, [:ast, :fg, :trb])
# Out:
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Gadfly.ji for module Gadfly.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Codecs.ji for module Codecs.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Colors.ji for module Colors.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/FixedPointNumbers.ji for module FixedPointNumbers.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/ColorTypes.ji for module ColorTypes.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Compose.ji for module Compose.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Iterators.ji for module Iterators.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/DataStructures.ji for module DataStructures.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Graphics.ji for module Graphics.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Showoff.ji for module Showoff.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Distributions.ji for module Distributions.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/PDMats.ji for module PDMats.
# WARNING: eval from module Compose to Gadfly:
# Expr(:import, :Patchwork)::Any
#   ** incremental compilation may be broken for this module **
#
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Hexagons.ji for module Hexagons.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Contour.ji for module Contour.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/ImmutableArrays.ji for module ImmutableArrays.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Distances.ji for module Distances.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Loess.ji for module Loess.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/NaNMath.ji for module NaNMath.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/DualNumbers.ji for module DualNumbers.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Calculus.ji for module Calculus.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/KernelDensity.ji for module KernelDensity.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Optim.ji for module Optim.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Grid.ji for module Grid.
# WARNING: color("black") is deprecated, use colorant"black" or parse(Colorant, "black")
# Compose.SVG(150.0,150.0,IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=568191, maxsize=Inf, ptr=568192, mark=-1),nothing,"fig-c45a19f0c3dd4c40a283c80dc6f28b58",0,Compose.SVGPropertyFrame[],Dict{Type{T},Union{Compose.Property{P<:Compose.PropertyPrimitive},Void}}(Compose.Property{Compose.SVGAttributePrimitive}=>nothing,Compose.Property{Compose.VisiblePrimitive}=>nothing),Dict{Compose.ClipPrimitive{P<:Compose.Point{XM<:Compose.Measure{S,T},YM<:Compose.Measure{S,T}}},AbstractString}(Compose.ClipPrimitive{Compose.Point{Compose.Measure{Compose.MeasureNil,Compose.MeasureNil},Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}}}([Compose.Point{Compose.Measure{Compose.MeasureNil,Compose.MeasureNil},Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}}(Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(55.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(5.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0)),Compose.Point{Compose.Measure{Compose.MeasureNil,Compose.MeasureNil},Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}}(Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(95.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(5.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0)),Compose.Point{Compose.Measure{Compose.MeasureNil,Compose.MeasureNil},Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}}(Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(95.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(45.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0)),Compose.Point{Compose.Measure{Compose.MeasureNil,Compose.MeasureNil},Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}}(Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(55.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(45.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0))])=>"fig-c45a19f0c3dd4c40a283c80dc6f28b58-element-85",Compose.ClipPrimitive{Compose.Point{Compose.Measure{Compose.MeasureNil,Compose.MeasureNil},Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}}}([Compose.Point{Compose.Measure{Compose.MeasureNil,Compose.MeasureNil},Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}}(Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(105.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(5.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0)),Compose.Point{Compose.Measure{Compose.MeasureNil,Compose.MeasureNil},Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}}(Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(145.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(5.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0)),Compose.Point{Compose.Measure{Compose.MeasureNil,Compose.MeasureNil},Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}}(Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(145.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(45.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0)),Compose.Point{Compose.Measure{Compose.MeasureNil,Compose.MeasureNil},Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}}(Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(105.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(45.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0))])=>"fig-c45a19f0c3dd4c40a283c80dc6f28b58-element-69",Compose.ClipPrimitive{Compose.Point{Compose.Measure{Compose.MeasureNil,Compose.MeasureNil},Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}}}([Compose.Point{Compose.Measure{Compose.MeasureNil,Compose.MeasureNil},Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}}(Compose.Mea ...
#  in depwarn at deprecated.jl:73
#  in color at /Users/brianeng/.julia/v0.4/Colors/src/parse.jl:145
#  in scatterplot_matrix at In[5]:7
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /Users/brianeng/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /Users/brianeng/.julia/v0.4/IJulia/src/IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[5], in expression starting on line 17

# %% [markdown]
# Make clusters of the players
# --------------------------

# %%
using Clustering
badcolumns = Symbol[]
for nbacolumn in names(nba)
    if (size(findin(isna(nba[nbacolumn]),true),1) > 0) || (typeof(nba[nbacolumn]) == DataArrays.DataArray{UTF8String,1})
        push!(badcolumns,nbacolumn)
    end
end
nbaclean = nba[:, filter(x -> !(x in badcolumns), names(nba))]
matrix = transpose(array(nbaclean))
floatmatrix = convert(Array{Float64,2},matrix)
clusters = kmeans(floatmatrix, 5)
labels = assignments(clusters)
# Out:
# WARNING: array(df::AbstractDataFrame) is deprecated, use convert(Array,df) instead.
# 481-element Array{Int64,1}:
#  5
#  5
#  5
#  4
#  5
#  2
#  4
#  5
#  3
#  3
#  1
#  2
#  3
#  ⋮
#  5
#  5
#  3
#  2
#  5
#  2
#  5
#  1
#  1
#  4
#  3
#  5
#  in depwarn at deprecated.jl:73
#  in array at deprecated.jl:50
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /Users/brianeng/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /Users/brianeng/.julia/v0.4/IJulia/src/IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[7], in expression starting on line 9

# %% [markdown]
# Plot players by cluster
# ----------------------

# %%
using MultivariateStats, Gadfly
M = fit(PCA, floatmatrix; maxoutdim=100)
plot_columns = transform(M,floatmatrix)[1:2,:]
plot_columns = transpose(plot_columns)
pl = plot(x=plot_columns[:,1], y=plot_columns[:,2], color=labels, Geom.point)
# Out:
# Plot(...)

# %% [markdown]
# Splitting into training and test sets
# -----------------------------------

# %%
n = size(nba,1)
is_train = shuffle([1:n] .> floor(n * .2))
train,test = nba[is_train,:],nba[!is_train,:]
# Out:
# (385x31 DataFrames.DataFrame
# | Row | player              | pos  | age | bref_team_id | g  | gs | mp   | fg  |
# |-----|---------------------|------|-----|--------------|----|----|------|-----|
# | 1   | "Quincy Acy"        | "SF" | 23  | "TOT"        | 63 | 0  | 847  | 66  |
# | 2   | "Steven Adams"      | "C"  | 20  | "OKC"        | 81 | 20 | 1197 | 93  |
# | 3   | "Jeff Adrien"       | "PF" | 27  | "TOT"        | 53 | 12 | 961  | 143 |
# | 4   | "Arron Afflalo"     | "SG" | 28  | "ORL"        | 73 | 73 | 2552 | 464 |
# | 5   | "Alexis Ajinca"     | "C"  | 25  | "NOP"        | 56 | 30 | 951  | 136 |
# | 6   | "Cole Aldrich"      | "C"  | 25  | "NYK"        | 46 | 2  | 330  | 33  |
# | 7   | "LaMarcus Aldridge" | "PF" | 28  | "POR"        | 69 | 69 | 2498 | 652 |
# | 8   | "Lavoy Allen"       | "PF" | 24  | "TOT"        | 65 | 2  | 1072 | 134 |
# | 9   | "Tony Allen"        | "SG" | 32  | "MEM"        | 55 | 28 | 1278 | 204 |
# | 10  | "Al-Farouq Aminu"   | "SF" | 23  | "NOP"        | 80 | 65 | 2045 | 234 |
# | 11  | "Louis Amundson"    | "PF" | 31  | "TOT"        | 19 | 0  | 185  | 16  |
# ⋮
# | 374 | "Louis Williams"    | "PG" | 27  | "ATL"        | 60 | 7  | 1445 | 197 |
# | 375 | "Marvin Williams"   | "PF" | 27  | "UTA"        | 66 | 50 | 1674 | 231 |
# | 376 | "Reggie Williams"   | "SF" | 27  | "OKC"        | 3  | 0  | 17   | 5   |
# | 377 | "Shawne Williams"   | "PF" | 27  | "LAL"        | 36 | 13 | 751  | 73  |
# | 378 | "Nate Wolters"      | "PG" | 22  | "MIL"        | 58 | 31 | 1309 | 170 |
# | 379 | "Brandan Wright"    | "C"  | 26  | "DAL"        | 58 | 0  | 1077 | 224 |
# | 380 | "Chris Wright"      | "SF" | 25  | "MIL"        | 8  | 0  | 126  | 21  |
# | 381 | "Dorell Wright"     | "SF" | 28  | "POR"        | 68 | 13 | 984  | 111 |
# | 382 | "Tony Wroten"       | "SG" | 20  | "PHI"        | 72 | 16 | 1765 | 345 |
# | 383 | "Nick Young"        | "SG" | 28  | "LAL"        | 64 | 9  | 1810 | 387 |
# | 384 | "Thaddeus Young"    | "PF" | 25  | "PHI"        | 79 | 78 | 2718 | 582 |
# | 385 | "Cody Zeller"       | "C"  | 21  | "CHA"        | 82 | 3  | 1416 | 172 |
#
# | Row | fga  | fg_   | x3p | x3pa | x3p_     | x2p | x2pa | x2p_     | efg_  |
# |-----|------|-------|-----|------|----------|-----|------|----------|-------|
# | 1   | 141  | 0.468 | 4   | 15   | 0.266667 | 62  | 126  | 0.492063 | 0.482 |
# | 2   | 185  | 0.503 | 0   | 0    | NA       | 93  | 185  | 0.502703 | 0.503 |
# | 3   | "Ryan Anderson"         | "PF" | 25  | "NOP"        | 22 | 14 | 795  |
# | 4   | "Giannis Antetokounmpo" | "SF" | 19  | "MIL"        | 77 | 23 | 1897 |
# | 5   | "Joel Anthony"          | "C"  | 31  | "TOT"        | 33 | 0  | 186  |
# | 6   | "Trevor Ariza"          | "SF" | 28  | "WAS"        | 77 | 77 | 2723 |
# | 7   | "Darrell Arthur"        | "SF" | 25  | "DEN"        | 68 | 1  | 1161 |
# | 8   | "Gustavo Ayon"          | "C"  | 28  | "ATL"        | 26 | 14 | 429  |
# | 9   | "Chris Babb"            | "SG" | 23  | "BOS"        | 14 | 0  | 132  |
# | 10  | "Jerryd Bayless"        | "PG" | 25  | "TOT"        | 72 | 19 | 1686 |
# | 11  | "Aron Baynes"           | "C"  | 27  | "SAS"        | 53 | 4  | 491  |
# ⋮
# | 85  | "Jamaal Tinsley"        | "PG" | 35  | "UTA"        | 8  | 5  | 110  |
# | 86  | "Ronny Turiaf"          | "PF" | 31  | "MIN"        | 31 | 10 | 606  |
# | 87  | "Greivis Vasquez"       | "SG" | 27  | "TOT"        | 79 | 23 | 1779 |
# | 88  | "Nikola Vucevic"        | "C"  | 23  | "ORL"        | 57 | 57 | 1812 |
# | 89  | "Kemba Walker"          | "PG" | 23  | "CHA"        | 73 | 73 | 2614 |
# | 90  | "Gerald Wallace"        | "SF" | 31  | "BOS"        | 58 | 16 | 1416 |
# | 91  | "C.J. Watson"           | "PG" | 29  | "IND"        | 63 | 5  | 1193 |
# | 92  | "Deron Williams"        | "PG" | 29  | "BRK"        | 64 | 58 | 2059 |
# | 93  | "Mo Williams"           | "PG" | 31  | "POR"        | 74 | 0  | 1834 |
# | 94  | "Jeff Withey"           | "C"  | 23  | "NOP"        | 58 | 4  | 684  |
# | 95  | "Metta World Peace"     | "SF" | 34  | "NYK"        | 29 | 1  | 388  |
# | 96  | "Tyler Zeller"          | "C"  | 24  | "CLE"        | 70 | 9  | 1049 |
#
# | Row | fg  | fga  | fg_   | x3p | x3pa | x3p_      | x2p | x2pa | x2p_     |
# |-----|-----|------|-------|-----|------|-----------|-----|------|----------|
# | 1   | 240 | 543  | 0.442 | 116 | 309  | 0.375405  | 124 | 234  | 0.529915 |
# | 2   | 177 | 275  | 0.644 | 3   | 12   | 0.25      | 174 | 263  | 0.661597 |
# | 3   | 155 | 354  | 0.438 | 67  | 164  | 0.408537  | 88  | 190  | 0.463158 |
# | 4   | 173 | 418  | 0.414 | 41  | 118  | 0.347458  | 132 | 300  | 0.44     |
# | 5   | 12  | 32   | 0.375 | 0   | 0    | NA        | 12  | 32   | 0.375    |
# | 6   | 389 | 853  | 0.456 | 180 | 442  | 0.40724   | 209 | 411  | 0.508516 |
# | 7   | 162 | 410  | 0.395 | 24  | 64   | 0.375     | 138 | 346  | 0.398844 |
# | 8   | 52  | 102  | 0.51  | 0   | 0    | NA        | 52  | 102  | 0.509804 |
# | 9   | 8   | 30   | 0.267 | 6   | 27   | 0.222222  | 2   | 3    | 0.666667 |
# | 10  | 248 | 617  | 0.402 | 76  | 212  | 0.358491  | 172 | 405  | 0.424691 |
# | 11  | 71  | 163  | 0.436 | 0   | 0    | NA        | 71  | 163  | 0.435583 |
# ⋮
# | 85  | 4   | 20   | 0.2   | 1   | 15   | 0.0666667 | 3   | 5    | 0.6      |
# | 86  | 64  | 107  | 0.598 | 0   | 0    | NA        | 64  | 107  | 0.598131 |
# | 87  | 277 | 658  | 0.421 | 109 | 289  | 0.377163  | 168 | 369  | 0.455285 |
# | 88  | 353 | 696  | 0.507 | 0   | 0    | NA        | 353 | 696  | 0.507184 |
# | 89  | 449 | 1143 | 0.393 | 109 | 327  | 0.333333  | 340 | 816  | 0.416667 |
# | 90  | 116 | 230  | 0.504 | 19  | 64   | 0.296875  | 97  | 166  | 0.584337 |
# | 91  | 146 | 334  | 0.437 | 53  | 145  | 0.365517  | 93  | 189  | 0.492063 |
# | 92  | 322 | 716  | 0.45  | 98  | 268  | 0.365672  | 224 | 448  | 0.5      |
# | 93  | 280 | 672  | 0.417 | 83  | 225  | 0.368889  | 197 | 447  | 0.440716 |
# | 94  | 69  | 129  | 0.535 | 0   | 1    | 0.0       | 69  | 128  | 0.539063 |
# | 95  | 56  | 141  | 0.397 | 17  | 54   | 0.314815  | 39  | 87   | 0.448276 |
# | 96  | 156 | 290  | 0.538 | 0   | 1    | 0.0       | 156 | 289  | 0.539792 |
#
# | Row | efg_  | ft  | fta | ft_   | orb | drb | trb | ast | stl | blk | tov |
# |-----|-------|-----|-----|-------|-----|-----|-----|-----|-----|-----|-----|
# | 1   | 0.549 | 105 | 116 | 0.905 | 23  | 182 | 205 | 143 | 54  | 8   | 84  |
# | 2   | 0.649 | 120 | 169 | 0.71  | 129 | 250 | 379 | 19  | 32  | 97  | 53  |
# | 3   | 0.532 | 59  | 62  | 0.952 | 66  | 76  | 142 | 17  | 10  | 7   | 20  |
# | 4   | 0.463 | 138 | 202 | 0.683 | 78  | 261 | 339 | 150 | 60  | 61  | 122 |
# | 5   | 0.375 | 4   | 8   | 0.5   | 15  | 23  | 38  | 2   | 3   | 12  | 3   |
# | 6   | 0.562 | 149 | 193 | 0.772 | 99  | 376 | 475 | 191 | 126 | 20  | 132 |
# | 7   | 0.424 | 53  | 62  | 0.855 | 52  | 158 | 210 | 61  | 39  | 47  | 58  |
# | 8   | 0.51  | 8   | 20  | 0.4   | 42  | 83  | 125 | 28  | 25  | 10  | 29  |
# | 9   | 0.367 | 0   | 0   | NA    | 4   | 13  | 17  | 3   | 6   | 0   | 3   |
# | 10  | 0.464 | 94  | 118 | 0.797 | 22  | 123 | 145 | 194 | 60  | 9   | 82  |
# | 11  | 0.436 | 19  | 21  | 0.905 | 57  | 88  | 145 | 34  | 2   | 5   | 36  |
# ⋮
# | 85  | 0.225 | 0   | 0   | NA    | 2   | 9   | 11  | 23  | 2   | 0   | 9   |
# | 86  | 0.598 | 21  | 50  | 0.42  | 55  | 119 | 174 | 24  | 8   | 50  | 24  |
# | 87  | 0.504 | 95  | 108 | 0.88  | 20  | 153 | 173 | 323 | 31  | 5   | 128 |
# | 88  | 0.507 | 105 | 137 | 0.766 | 185 | 441 | 626 | 104 | 60  | 47  | 112 |
# | 89  | 0.441 | 282 | 337 | 0.837 | 39  | 267 | 306 | 447 | 86  | 32  | 169 |
# | 90  | 0.546 | 47  | 101 | 0.465 | 36  | 176 | 212 | 143 | 73  | 14  | 97  |
# | 91  | 0.516 | 69  | 88  | 0.784 | 19  | 82  | 101 | 107 | 60  | 8   | 60  |
# | 92  | 0.518 | 173 | 216 | 0.801 | 15  | 153 | 168 | 392 | 93  | 13  | 143 |
# | 93  | 0.478 | 78  | 89  | 0.876 | 42  | 111 | 153 | 321 | 55  | 10  | 149 |
# | 94  | 0.535 | 52  | 73  | 0.712 | 49  | 101 | 150 | 26  | 15  | 50  | 20  |
# | 95  | 0.457 | 10  | 16  | 0.625 | 18  | 41  | 59  | 17  | 24  | 8   | 19  |
# | 96  | 0.538 | 87  | 121 | 0.719 | 103 | 179 | 282 | 36  | 18  | 38  | 60  |
#
# | Row | pf  | pts  | season      | season_end |
# |-----|-----|------|-------------|------------|
# | 1   | 115 | 701  | "2013-2014" | 2013       |
# | 2   | 162 | 477  | "2013-2014" | 2013       |
# | 3   | 47  | 436  | "2013-2014" | 2013       |
# | 4   | 173 | 525  | "2013-2014" | 2013       |
# | 5   | 17  | 28   | "2013-2014" | 2013       |
# | 6   | 179 | 1107 | "2013-2014" | 2013       |
# | 7   | 185 | 401  | "2013-2014" | 2013       |
# | 8   | 47  | 112  | "2013-2014" | 2013       |
# | 9   | 13  | 22   | "2013-2014" | 2013       |
# | 10  | 161 | 666  | "2013-2014" | 2013       |
# | 11  | 77  | 161  | "2013-2014" | 2013       |
# ⋮
# | 85  | 10  | 9    | "2013-2014" | 2013       |
# | 86  | 65  | 149  | "2013-2014" | 2013       |
# | 87  | 143 | 758  | "2013-2014" | 2013       |
# | 88  | 169 | 811  | "2013-2014" | 2013       |
# | 89  | 128 | 1289 | "2013-2014" | 2013       |
# | 90  | 79  | 298  | "2013-2014" | 2013       |
# | 91  | 66  | 414  | "2013-2014" | 2013       |
# | 92  | 148 | 915  | "2013-2014" | 2013       |
# | 93  | 197 | 721  | "2013-2014" | 2013       |
# | 94  | 73  | 190  | "2013-2014" | 2013       |
# | 95  | 44  | 139  | "2013-2014" | 2013       |
# | 96  | 137 | 399  | "2013-2014" | 2013       |)

# %% [markdown]
# Univariate linear regression
# ---------------------------

# %%
using GLM
data = DataFrame(X=train[:fg],Y=train[:ast])
OLS = glm(Y~X,data,Normal(),IdentityLink())
testdata = convert(Array{Float64,1},test[:fg])
model = coef(OLS)
predictions = model[2].*testdata + model[1]
# Out:
# 96-element Array{Float64,1}:
#  136.912
#  103.161
#   91.3752
#  101.018
#   14.7671
#  216.734
#   95.1253
#   36.1959
#   12.6242
#  141.197
#   46.3746
#   87.0894
#  134.233
#    ⋮
#   10.4813
#   42.6246
#  156.733
#  197.448
#  248.877
#   70.4821
#   86.5537
#  180.841
#  158.34
#   45.3032
#   38.3388
#   91.9109

# %% [markdown]
# Calculate summary statistics for the model
# -----------------------------------------

# %%
OLS
stderr(OLS)
vcov(OLS)
# Out:
# 2x2 Array{Float64,2}:
#  54.121    -0.15459
#  -0.15459   0.0007897

# %% [markdown]
# Fit a random forest model
# ------------------------

# %%
using DecisionTree
predictor_columns = [:age, :mp, :fg, :trb, :stl, :blk]
yTrain = convert(Array{Float64,1},train[:ast])
xTrain = convert(Array{Float64,2},array(train[predictor_columns]))
model = build_forest(yTrain, xTrain, 2, 100, 1.0)
xTest = convert(Array{Float64,2},array(test[predictor_columns]))
predTest = apply_forest(model, xTest)
# Out:
# WARNING: array(df::AbstractDataFrame) is deprecated, use convert(Array,df) instead.
#  in depwarn at deprecated.jl:73
#  in array at deprecated.jl:50
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /Users/brianeng/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /Users/brianeng/.julia/v0.4/IJulia/src/IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[12], in expression starting on line 4
# 96-element Array{Float64,1}:
#  232.67
#   73.52
#   71.31
#  106.46
#    7.40667
#  346.83
#   62.9133
#   40.7133
#    9.1
#  202.94
#   28.88
#  100.93
#   90.25
#    ⋮
#    5.99
#   24.26
#  151.63
#  134.05
#  255.49
#  158.97
#  182.685
#  278.76
#  212.76
#   24.98
#   44.05
#   38.0

# %% [markdown]
# Calculate error
# --------------

# %%
accuracy = nfoldCV_forest(yTrain, xTrain, 2, 100, 3, 1.0)
# Out:
# Fold 1
# Mean Squared Error:     8832.091289947917
# Correlation Coeff:      0.772917080811357
# Coeff of Determination: 0.5952103421082209
#
# Fold 2
# Mean Squared Error:     4005.96655241059
# Correlation Coeff:      0.8352609440133755
# Coeff of Determination: 0.6592257328222768
#
# Fold 3
# 3-element Array{Float64,1}:
#  0.59521
#  0.659226
#  0.699082
# Mean Squared Error:     5819.666788869221
# Correlation Coeff:      0.8537207740392146
# Coeff of Determination: 0.6990823826209236
#
# Mean Coeff of Determination: 0.6511728191838071

# %% [markdown]
# Download a webpage
# -----------------

# %%
using Requests
url = "http://www.basketball-reference.com/boxscores/201506140GSW.html"
data = readall(get(url))
# Out:
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Requests.ji for module Requests.
# INFO: Recompiling stale cache file /Users/brianeng/.julia/lib/v0.4/Zlib.ji for module Zlib.
# "<!DOCTYPE html><html data-version=\"the-magglio-475\" itemscope itemtype=\"http://schema.org/website\" xmlns:fb=\"http://www.facebook.com/2008/fbml\" xmlns:og=\"http://opengraphprotocol.org/schema/\" lang=\"en\"><head><title>Cleveland Cavaliers at Golden State Warriors Box Score, June 14, 2015 | Basketball-Reference.com</title><link rel=\"dns-prefetch\" href=\"http://d2ft4b0ve1aur1.cloudfront.net\" /><link rel=\"dns-prefetch\" href=\"http://m.bkref.com\" />\n<link rel=subresource href=\"http://d2ft4b0ve1aur1.cloudfront.net/js-475/sr-bbr-min.js.jgz\" /><script type=\"text/javascript\">var sr_gzipEnabled = false; var sr_js_loader = new Array();</script><script type=\"text/javascript\" src=\"http://d2ft4b0ve1aur1.cloudfront.net/js-100/sr.gzipcheck.js.jgz\"></script><noscript><link type=\"text/css\" rel=\"stylesheet\" href=\"http://d2ft4b0ve1aur1.cloudfront.net/css-475/sr-bbr-min.css\"></noscript><script type=\"text/javascript\">\n(function () {var sr_css_file = 'http://d2ft4b0ve1aur1.cloudfront.net/css-475/sr-bbr-min.css';if (sr_gzipEnabled) {sr_css_file = 'http://d2ft4b0ve1aur1.cloudfront.net/css-475/sr-bbr-min-gz.css';}var head = document.getElementsByTagName(\"head\")[0];if (head) {var scriptStyles = document.createElement(\"link\");scriptStyles.rel = \"stylesheet\";scriptStyles.type = \"text/css\";scriptStyles.href = sr_css_file;head.appendChild(scriptStyles);}}());</script><!-- tiles, touch, favicons --><link rel=\"apple-touch-icon-precomposed\" sizes=\"152x152\" href=\"http://d2ft4b0ve1aur1.cloudfront.net/images-475/apple-touch-icon-152x152-bbr-precomposed.png\"><link rel=\"apple-touch-icon-precomposed\" sizes=\"144x144\" href=\"http://d2ft4b0ve1aur1.cloudfront.net/images-475/apple-touch-icon-144x144-bbr-precomposed.png\"><link rel=\"apple-touch-icon-precomposed\" sizes=\"120x120\" href=\"http://d2ft4b0ve1aur1.cloudfront.net/images-475/apple-touch-icon-120x120-bbr-precomposed.png\"><link rel=\"apple-touch-icon-precomposed\" sizes=\"114x114\" href=\"http://d2ft4b0ve1aur1.cloudfront.net/images-475/apple-touch-icon-114x114-bbr-precomposed.png\"><link rel=\"apple-touch-icon-precomposed\" sizes=\"76x76\" href=\"http://d2ft4b0ve1aur1.cloudfront.net/images-475/apple-touch-icon-76x76-bbr-precomposed.png\"><link rel=\"apple-touch-icon-precomposed\" sizes=\"72x72\" href=\"http://d2ft4b0ve1aur1.cloudfront.net/images-475/apple-touch-icon-72x72-bbr-precomposed.png\"><link rel=\"apple-touch-icon-precomposed\" href=\"http://d2ft4b0ve1aur1.cloudfront.net/images-475/apple-touch-icon-bbr-precomposed.png\"><link rel=icon href=\"http://d2ft4b0ve1aur1.cloudfront.net/images-475/favicon_bbr.png\"><!--[if IE]><link rel=\"shortcut icon\" href=\"http://d2ft4b0ve1aur1.cloudfront.net/images-475/favicon_bbr.ico\"><![endif]--><meta name=\"msapplication-TileColor\" content=\"#ffffff\"/><meta name=\"msapplication-TileImage\" content=\"http://d2ft4b0ve1aur1.cloudfront.net/images-475/ms-tile-144-bbr.png\" /><link rel=search        type=\"application/opensearchdescription+xml\" href=\"http://d2ft4b0ve1aur1.cloudfront.net/os-475/opensearch-bbr.xml\" title=\"B-Ref Search\"><!--[if lte IE 7 ]><style type=\"text/css\">\n.uni_holder { display: none; }\n</style><![endif]--><!--[if lte IE 6]><style type=\"text/css\">\n.hovermenu,.hovermenu_ajax,.sub_index,#quick_index {display:none!important}\n</style><![endif]-->\n<!--  ASYNCHRONOUS:googletag --><script type='text/javascript'>\nvar googletag = googletag || {};googletag.cmd = googletag.cmd || [];(function() {var gads = document.createElement('script');gads.async = true;gads.type = 'text/javascript';var useSSL = 'https:' == document.location.protocol;gads.src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js';var node = document.getElementsByTagName('script')[0];node.parentNode.insertBefore(gads, node);})();</script><meta name=keywords content=\"box score, play-by-play, shot chart, June 14, 2015, Cleveland Cavaliers, Golden State Warriors\"><meta property=\"fb:admins\"     content=\"34208 ...

# %% [markdown]
# Extract player box scores
# ------------------------

# %%
using Gumbo
doc = parsehtml(data)
cleveland_table = HTMLElement{:any}
gsw_table = HTMLElement{:any}
for elem in preorder(doc.root)
    if typeof(elem) == HTMLElement{:table}
        if haskey(attrs(elem),"id")
            if attrs(elem)["id"] == "CLE_basic"
                cleveland_table = elem
            elseif attrs(elem)["id"] == "GSW_basic"
                gsw_table = elem
            end
        end
    end
end

function search_table(table)
    results = []
    for elem in preorder(table)
        if typeof(elem) == HTMLElement{:tr}
            temp_results = []
            for sub_elem in preorder(elem)
                if typeof(sub_elem) == HTMLText
                    push!(temp_results,sub_elem)
                end
            end
            push!(results,temp_results)
        end
    end
    return results
end

cleveland_results = search_table(cleveland_table)
gsw_results = search_table(gsw_table)
